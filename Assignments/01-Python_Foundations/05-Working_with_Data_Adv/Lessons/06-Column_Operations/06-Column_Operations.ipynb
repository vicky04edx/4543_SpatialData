# %% [markdown]
# # 🧱 Column Operations: Creating, Renaming, and Dropping Columns
#
# ## 🔹 LEARNING GOALS:
# - Create new columns using calculations or functions
# - Rename one or multiple columns
# - Drop unwanted columns safely
# - Apply functions across columns using `.apply()` and lambdas

# %% [markdown]
# ### 🏗️ 1. Setup and Sample Data

# %%
import pandas as pd

data = {
    "first_name": ["Alice", "Bob", "Charlie", "David"],
    "last_name": ["Smith", "Jones", "Brown", "Wilson"],
    "math_score": [85, 90, 78, 92],
    "science_score": [88, 85, 82, 95]
}

df = pd.DataFrame(data)
df
# Out:
#   first_name last_name  math_score  science_score
# 0      Alice     Smith          85             88
# 1        Bob     Jones          90             85
# 2    Charlie     Brown          78             82
# 3      David    Wilson          92             95

# %% [markdown]
# ### ➕ 2. Creating New Columns

# %%
# Simple column arithmetic
df["average_score"] = (df["math_score"] + df["science_score"]) / 2
df
# Out:
#   first_name last_name  math_score  science_score  average_score
# 0      Alice     Smith          85             88           86.5
# 1        Bob     Jones          90             85           87.5
# 2    Charlie     Brown          78             82           80.0
# 3      David    Wilson          92             95           93.5

# %%
# Create full name column
df["full_name"] = df["first_name"] + " " + df["last_name"]
df
# Out:
#   first_name last_name  math_score  science_score  average_score  \
# 0      Alice     Smith          85             88           86.5
# 1        Bob     Jones          90             85           87.5
# 2    Charlie     Brown          78             82           80.0
# 3      David    Wilson          92             95           93.5
#
#        full_name
# 0    Alice Smith
# 1      Bob Jones
# 2  Charlie Brown
# 3   David Wilson

# %% [markdown]
# ### ✍️ 3. Renaming Columns

# %%
# Rename a single column
df.rename(columns={"math_score": "Math", "science_score": "Science"}, inplace=True)
df
# Out:
#   first_name last_name  Math  Science  average_score      full_name
# 0      Alice     Smith    85       88           86.5    Alice Smith
# 1        Bob     Jones    90       85           87.5      Bob Jones
# 2    Charlie     Brown    78       82           80.0  Charlie Brown
# 3      David    Wilson    92       95           93.5   David Wilson

# %%
# Rename all columns to uppercase
df.columns = [col.upper() for col in df.columns]
df
# Out:
#   FIRST_NAME LAST_NAME  MATH  SCIENCE  AVERAGE_SCORE      FULL_NAME
# 0      Alice     Smith    85       88           86.5    Alice Smith
# 1        Bob     Jones    90       85           87.5      Bob Jones
# 2    Charlie     Brown    78       82           80.0  Charlie Brown
# 3      David    Wilson    92       95           93.5   David Wilson

# %% [markdown]
# ### ❌ 4. Dropping Columns

# %%
# Drop by name
df.drop(columns=["FULL_NAME"], inplace=True)
df
# Out:
#   FIRST_NAME LAST_NAME  MATH  SCIENCE  AVERAGE_SCORE
# 0      Alice     Smith    85       88           86.5
# 1        Bob     Jones    90       85           87.5
# 2    Charlie     Brown    78       82           80.0
# 3      David    Wilson    92       95           93.5

# %% [markdown]
# ### 🔁 5. Applying Functions Across Columns

# %%
# Categorize based on average score
def grade(score):
    if score >= 90:
        return "A"
    elif score >= 80:
        return "B"
    else:
        return "C"

df["GRADE"] = df["AVERAGE_SCORE"].apply(grade)
df
# Out:
#   FIRST_NAME LAST_NAME  MATH  SCIENCE  AVERAGE_SCORE GRADE
# 0      Alice     Smith    85       88           86.5     B
# 1        Bob     Jones    90       85           87.5     B
# 2    Charlie     Brown    78       82           80.0     B
# 3      David    Wilson    92       95           93.5     A

# %% [markdown]
# ### 🧪 Try It Yourself
#
# - Add a new column called `"NAME_LENGTH"` that contains the length of each `FIRST_NAME`
# - Create a column `"MATH_PLUS_5"` which is the math score + 5 points bonus

# %%
import pandas as pd

# Example dataset (replace with your actual file if needed)
data = {
    "FIRST_NAME": ["Alex", "Jordan", "Taylor", None, "Sam"],
    "MATH": [85, 90, 78, 88, None]
}

df = pd.DataFrame(data)

# -----------------------
# Feature Engineering
# -----------------------

# Safe NAME_LENGTH (handles None)
df["NAME_LENGTH"] = df["FIRST_NAME"].fillna("").str.len()

# Safe MATH_PLUS_5 (handles non-numeric / None)
df["MATH_PLUS_5"] = pd.to_numeric(df["MATH"], errors="coerce") + 5

# -----------------------
# Output
# -----------------------
print(df)
# Out:
#   FIRST_NAME  MATH  NAME_LENGTH  MATH_PLUS_5
# 0       Alex  85.0            4         90.0
# 1     Jordan  90.0            6         95.0
# 2     Taylor  78.0            6         83.0
# 3        NaN  88.0            0         93.0
# 4        Sam   NaN            3          NaN

# %% [markdown]
# ### 🧠 Mini-Challenge
#
# > Load `"data/students.csv"` and:
# - Create a `"total_score"` column by summing up all numeric test columns
# - Rename any columns that contain spaces (e.g., `"Test 1"`) to use underscores
# - Drop any column that contains only `NaN` values

# %%
import pandas as pd

# Load dataset
try:
	df = pd.read_csv("data/students.csv")
except FileNotFoundError:
	print("data/students.csv not found. Using sample data from the notebook.")
	df = pd.DataFrame(data)

df.columns = df.columns.str.replace(" ", "_")

numeric_cols = df.select_dtypes(include=["number"]).columns
df["total_score"] = df[numeric_cols].sum(axis=1)

df = df.dropna(axis=1, how="all")

print(df.head())
print("\nColumns:", df.columns)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 4
#       1 import pandas as pd
#       3 # Load dataset
# ----> 4 df = pd.read_csv("data/students.csv")
#       6 df.columns = df.columns.str.replace(" ", "_")
#       8 numeric_cols = df.select_dtypes(include=["number"]).columns
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\io\common.py:926, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     921 elif isinstance(handle, str):
#     922     # Check whether the filename is to be opened in binary mode.
#     923     # Binary mode does not support 'encoding' and 'newline'.
#     924     if ioargs.encoding and "b" not in ioargs.mode:
#     925         # Encoding
# --> 926         handle = open(
#     927             handle,
#     928             ioargs.mode,
#     929             encoding=ioargs.encoding,
#     930             errors=errors,
#     931             newline="",
#     932         )
#     933     else:
#     934         # Binary mode
#     935         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/students.csv'

# %% [markdown]
# ### 📝 Summary
#
# | Action             | Method                                |
# |--------------------|----------------------------------------|
# | Create column       | `df["new"] = ...`                     |
# | Rename column(s)    | `df.rename(columns={...})`            |
# | Rename all columns  | `df.columns = [...]`                 |
# | Drop column(s)      | `df.drop(columns=[...])`              |
# | Apply function      | `df["col"].apply(func)`               |
