# %% [markdown]
# # 🧮 Sorting & Filtering in Pandas
#
# ## 🔹 LEARNING GOALS:
# - Sort rows using `.sort_values()`
# - Filter data using conditional logic
# - Chain multiple filters together
# - Use `.query()` for readable filtering

# %% [markdown]
# ### 📥 1. Load the Dataset

# %%
import pandas as pd

df = pd.read_csv("../../data/students.csv")
df.head()
# Out:
#   first_name last_name  math_score  science_score
# 0   Danielle      Wood         100             95
# 1      Angel     Clark          67             78
# 2     Joshua     Adams          61            100
# 3    Jeffrey    Zuniga          77             99
# 4       Jill      Wong          75             83

# %% [markdown]
# ### 🔢 2. Sorting Data

# %%
# Sort by math_score
df.sort_values(by="math_score")
# Out:
#      first_name  last_name  math_score  science_score
# 28      Melanie      Baker          60             94
# 2        Joshua      Adams          61            100
# 13        James      Cohen          61             66
# 19         Adam      Adams          61             70
# 44  Christopher      Brown          62             64
# 12      Anthony    Hawkins          62             74
# 49      Michael   Valencia          65             91
# 14        Debra    Cameron          65             84
# 37    Christine      Hicks          65             80
# 9       Anthony       Gray          65             74
# 36        Maria     Bright          66             74
# 39      Barbara   Williams          66             74
# 7   Christopher     Daniel          66             64
# 47       Joshua       Rice          67             80
# 1         Angel      Clark          67             78
# 6      Patricia    Jackson          68             72
# 33       Teresa      Hurst          69             77
# 29    Cassandra     Wright          70             75
# 21        Helen       Hahn          72             82
# 34     Nicholas       Ross          73            100
# 15          Amy    Parsons          73             77
# 24        Susan       Rios          74             64
# 5         Erica      Lynch          74             96
# 16      Jeffrey      Perez          74             89
# 4          Jill       Wong          75             83
# 43        Keith  Henderson          76             77
# 3       Jeffrey     Zuniga          77             99
# 27        Colin      Ellis          77             70
# 32       Amanda   Richards          77             84
# 35       Andrea   Robinson          81             95
# 31      Jessica      Baker          81             89
# 40        Janet  Rodriguez          82             62
# 41      Brandon     Burton          82             80
# 48      Cynthia     Maddox          84             73
# 38     Michelle      Davis          84             63
# 23         Eric    Edwards          86             77
# 11      William     Bowman          87             65
# 30      Lindsay    Hoffman          87             70
# 25      Matthew     Foster          88             98
# 45        Jesse      James          89             73
# 17      Bridget    Johnson          92            100
# 46        Craig    Ferrell          94             96
# 22      Matthew     Walter          94             73
# 8        Robert     Martin          94             62
# 20        Linda      Clark          95             83
# 10      Jeffery       Mayo          97             78
# 26  Christopher      Rocha          97            100
# 18         Lisa    Stewart          98             83
# 42       Jeremy     Conner          98             85
# 0      Danielle       Wood         100             95

# %%
# Sort by science_score descending
df.sort_values(by="science_score", ascending=False)
# Out:
#      first_name  last_name  math_score  science_score
# 17      Bridget    Johnson          92            100
# 2        Joshua      Adams          61            100
# 34     Nicholas       Ross          73            100
# 26  Christopher      Rocha          97            100
# 3       Jeffrey     Zuniga          77             99
# 25      Matthew     Foster          88             98
# 46        Craig    Ferrell          94             96
# 5         Erica      Lynch          74             96
# 35       Andrea   Robinson          81             95
# 0      Danielle       Wood         100             95
# 28      Melanie      Baker          60             94
# 49      Michael   Valencia          65             91
# 16      Jeffrey      Perez          74             89
# 31      Jessica      Baker          81             89
# 42       Jeremy     Conner          98             85
# 14        Debra    Cameron          65             84
# 32       Amanda   Richards          77             84
# 4          Jill       Wong          75             83
# 18         Lisa    Stewart          98             83
# 20        Linda      Clark          95             83
# 21        Helen       Hahn          72             82
# 47       Joshua       Rice          67             80
# 41      Brandon     Burton          82             80
# 37    Christine      Hicks          65             80
# 1         Angel      Clark          67             78
# 10      Jeffery       Mayo          97             78
# 43        Keith  Henderson          76             77
# 23         Eric    Edwards          86             77
# 33       Teresa      Hurst          69             77
# 15          Amy    Parsons          73             77
# 29    Cassandra     Wright          70             75
# 36        Maria     Bright          66             74
# 39      Barbara   Williams          66             74
# 12      Anthony    Hawkins          62             74
# 9       Anthony       Gray          65             74
# 45        Jesse      James          89             73
# 22      Matthew     Walter          94             73
# 48      Cynthia     Maddox          84             73
# 6      Patricia    Jackson          68             72
# 30      Lindsay    Hoffman          87             70
# 27        Colin      Ellis          77             70
# 19         Adam      Adams          61             70
# 13        James      Cohen          61             66
# 11      William     Bowman          87             65
# 7   Christopher     Daniel          66             64
# 44  Christopher      Brown          62             64
# 24        Susan       Rios          74             64
# 38     Michelle      Davis          84             63
# 40        Janet  Rodriguez          82             62
# 8        Robert     Martin          94             62

# %%
# Sort by multiple columns
df.sort_values(by=["science_score", "math_score"], ascending=[False, True])
# Out:
#      first_name  last_name  math_score  science_score
# 2        Joshua      Adams          61            100
# 34     Nicholas       Ross          73            100
# 17      Bridget    Johnson          92            100
# 26  Christopher      Rocha          97            100
# 3       Jeffrey     Zuniga          77             99
# 25      Matthew     Foster          88             98
# 5         Erica      Lynch          74             96
# 46        Craig    Ferrell          94             96
# 35       Andrea   Robinson          81             95
# 0      Danielle       Wood         100             95
# 28      Melanie      Baker          60             94
# 49      Michael   Valencia          65             91
# 16      Jeffrey      Perez          74             89
# 31      Jessica      Baker          81             89
# 42       Jeremy     Conner          98             85
# 14        Debra    Cameron          65             84
# 32       Amanda   Richards          77             84
# 4          Jill       Wong          75             83
# 20        Linda      Clark          95             83
# 18         Lisa    Stewart          98             83
# 21        Helen       Hahn          72             82
# 37    Christine      Hicks          65             80
# 47       Joshua       Rice          67             80
# 41      Brandon     Burton          82             80
# 1         Angel      Clark          67             78
# 10      Jeffery       Mayo          97             78
# 33       Teresa      Hurst          69             77
# 15          Amy    Parsons          73             77
# 43        Keith  Henderson          76             77
# 23         Eric    Edwards          86             77
# 29    Cassandra     Wright          70             75
# 12      Anthony    Hawkins          62             74
# 9       Anthony       Gray          65             74
# 36        Maria     Bright          66             74
# 39      Barbara   Williams          66             74
# 48      Cynthia     Maddox          84             73
# 45        Jesse      James          89             73
# 22      Matthew     Walter          94             73
# 6      Patricia    Jackson          68             72
# 19         Adam      Adams          61             70
# 27        Colin      Ellis          77             70
# 30      Lindsay    Hoffman          87             70
# 13        James      Cohen          61             66
# 11      William     Bowman          87             65
# 44  Christopher      Brown          62             64
# 7   Christopher     Daniel          66             64
# 24        Susan       Rios          74             64
# 38     Michelle      Davis          84             63
# 40        Janet  Rodriguez          82             62
# 8        Robert     Martin          94             62

# %% [markdown]
# ### 🧪 3. Filtering with Conditions

# %%
# Who scored at least 90 in math?
df[df["math_score"] >= 90]

# %%
# Who scored less than 70 in either subject?
df[(df["math_score"] < 70) | (df["science_score"] < 70)]

# %% [markdown]
# ### 🔗 4. Combining Filters

# %%
# Students with B+ or higher in both
df[(df["math_score"] >= 87) & (df["science_score"] >= 87)]

# %% [markdown]
# ### 🧾 5. Using `.query()` for Readability

# %%
# Same query using .query()
df.query("math_score >= 87 and science_score >= 87")

# %% [markdown]
# ### 🧪 Try It Yourself
#
# - Sort the dataset by first name alphabetically
# - Find students with the same math and science score
# - Use `.query()` to find students who scored over 95 in *either* subject

# %%
import pandas as pd

df = pd.read_csv(r"c:\Users\Victoria Heredia\Downloads\4543_SpatialData\Assignments\01-Python_Foundations\04-Foundations\Lessons\04-Data_Input_Output\students.csv")

print(df.columns)

# Safe sort (first column fallback)
df_sorted = df.sort_values(by=df.columns[0])
print(df_sorted)

# Try sorting by FIRST_NAME (only if it exists)
if "FIRST_NAME" in df.columns:
    df_sorted = df.sort_values(by="FIRST_NAME")
    print("\nSorted by FIRST_NAME:")
    print(df_sorted)

# Same Math and Science score (only if columns exist)
if "MATH" in df.columns and "SCIENCE" in df.columns:
    same_scores = df[df["MATH"] == df["SCIENCE"]]
    print("\nSame Math and Science scores:")
    print(same_scores)

    high_scores = df.query("MATH > 95 or SCIENCE > 95")
    print("\nHigh scorers:")
    print(high_scores)
# Out:
# Index(['Name', 'Age', 'Score'], dtype='str')
#       Name  Age  Score
# 0    Alice   23     90
# 1      Bob   25     85
# 2  Charlie   22     95

# %% [markdown]
# ### 🧠 Mini-Challenge
#
# > Load `"data/survey.csv"` and:
# - Sort by the most recent signup date
# - Filter out anyone who didn't complete the survey (nulls or "N/A")
# - Use `.query()` to select rows with a specific condition of your choice

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("../../data/survey.csv")

# Normalize missing values
df = df.replace(["N/A", "n/a", ""], pd.NA)
df = df.dropna()

# Use the survey date column if signup_date is not available
if "signup_date" not in df.columns and "survey_date" in df.columns:
	df = df.rename(columns={"survey_date": "signup_date"})

if "signup_date" not in df.columns:
	raise KeyError("Expected 'signup_date' or 'survey_date' column in survey.csv")

df["signup_date"] = pd.to_datetime(df["signup_date"], errors="coerce")

# Remove rows where date couldn't be parsed
df = df.dropna(subset=["signup_date"])

df_sorted = df.sort_values(by="signup_date", ascending=False)
print("Most recent signups:")
print(df_sorted)

filtered = df.query("age > 25")
print("\nFiltered users (age > 25):")
print(filtered)
# Out:
# Most recent signups:
# Empty DataFrame
# Columns: [student_id, age, gender, major, gpa, study_hours_per_week, satisfaction_1_5, signup_date, dorm_resident, expected_grad_year, income_range, commute_minutes, clubs_member, attendance_rate, favorite_language, comments]
# Index: []
#
# Filtered users (age > 25):
# Empty DataFrame
# Columns: [student_id, age, gender, major, gpa, study_hours_per_week, satisfaction_1_5, signup_date, dorm_resident, expected_grad_year, income_range, commute_minutes, clubs_member, attendance_rate, favorite_language, comments]
# Index: []

# %% [markdown]
# ### 📝 Summary
#
# | Task              | Code Example                                 |
# |-------------------|-----------------------------------------------|
# | Sort by column     | `df.sort_values(by="col")`                  |
# | Filter condition   | `df[df["col"] > value]`                     |
# | Combine filters    | `df[(cond1) & (cond2)]`                     |
# | Query method       | `df.query("col > value and col2 < value")`  |
