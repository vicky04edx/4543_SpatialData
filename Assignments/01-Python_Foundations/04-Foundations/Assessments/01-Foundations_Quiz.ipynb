# %% [markdown]
# # 📝 Foundations Quiz
#
# This quiz covers material from the **Foundations** notebooks (01–08).
# Answer each question in the provided cell. Some questions require code, others are written answers.

# %% [markdown]
# ## Q1. Magics
# What does `%whos` display? Write your answer below.

# %% [markdown]
# *Your Answer:* Displays all currently defined variables in memory, including their names, types, and values.

# %% [markdown]
# ## Q2. Markdown
# Create a Markdown cell with a heading `## My Hobbies` and a bullet list of at least 3 hobbies.

# %% [markdown]
# *Your Answer:*

# %% [markdown]
# ## My Hobbies
#
# - Coding
# - Singing
# - Watch movies/series

# %% [markdown]
# ## Q3. Files and Paths
# Use `%pwd` to print your current working directory.

# %%
# %pwd
# Out:
# 'c:\\Users\\Victoria Heredia\\Downloads\\4543_SpatialData\\Assignments\\01-Python_Foundations\\04-Foundations\\Assessments'

# %% [markdown]
# ## Q4. File I/O
# Write Python code that saves `Hello World` to a file called `hello.txt`, then reads it back and prints the contents.

# %%
with open("hello.txt", "w") as file:
    file.write("Hello World")

with open("hello.txt", "r") as file:
    print(file.read())
# Out:
# Hello World

# %% [markdown]
# ## Q5. Data I/O
# Load the file `students.csv` (or create a small CSV yourself) with Pandas and show the first 5 rows.

# %%
import pandas as pd

df = pd.read_csv("students.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv("students.csv")
#       4 df.head()
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
# ...

# %% [markdown]
# ## Q6. Plotting
# Create a line plot of $y = x^2$ for $x$ values from 0 to 10.

# %%
import matplotlib.pyplot as plt

x = list(range(11))
y = [i**2 for i in x]

plt.plot(x, y)
plt.title("y = x^2")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %% [markdown]
# ## Q7. Shortcuts
# In Command mode, what keyboard shortcut deletes a cell?

# %% [markdown]
# *Your Answer:*

# %% [markdown]
# DD (press D twice in Command Mode)

# %% [markdown]
# ## Q8. Help and Docs
# Use `?` to display the docstring for `len`. Show the result.

# %%
len?

# %% [markdown]
# ## Q9. Timing
# Compare the runtime of squaring numbers using a Python loop vs. NumPy. Use `%timeit` for each.

# %%
import numpy as np

# %timeit [i**2 for i in range(1000)]
# %timeit np.arange(1000) ** 2
# Out:
# 140 μs ± 6.56 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 4.47 μs ± 129 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Q10. Reflection
# Why is it useful to mix Markdown and code in Jupyter notebooks? Write 2–3 sentences.

# %% [markdown]
# *Your Answer:*

# %% [markdown]
# Mixing Markdown and code makes notebooks easier to read and understand. Markdown allows explanations and structure, and code cells allow execution. Both make notebooks great for learning, documentation, and sharing results.
