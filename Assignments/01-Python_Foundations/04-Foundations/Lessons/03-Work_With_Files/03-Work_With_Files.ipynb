# %% [markdown]
# # 📂 03 - Working with Files and Paths
#
# Data science means working with files all the time: datasets, config files, logs.
# This notebook introduces:
# - Checking your current path in Jupyter
# - Navigating directories
# - Reading and writing text files
# - Using `with` for safe file handling
# - Basics of JSON and CSV I/O

# %% [markdown]
# ## 1. Where Am I?

# %%
# %pwd  # Print current working directory
# Out:
# 'c:\\Users\\Victoria Heredia\\Downloads\\4543_SpatialData\\Assignments\\01-Python_Foundations\\04-Foundations\\Lessons\\03-Work_With_Files'

# %%
# %ls  # List files in the current directory
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 389D-1836
#
#  Directory of c:\Users\Victoria Heredia\Downloads\4543_SpatialData\Assignments\01-Python_Foundations\04-Foundations\Lessons\03-Work_With_Files
#
#
#  Directory of c:\Users\Victoria Heredia\Downloads\4543_SpatialData\Assignments\01-Python_Foundations\04-Foundations\Lessons\03-Work_With_Files
#
#
#  Directory of c:\Users\Victoria Heredia\Downloads\4543_SpatialData\Assignments\01-Python_Foundations\04-Foundations\Lessons\03-Work_With_Files
#
#
#  Directory of c:\Users\Victoria Heredia\Downloads\4543_SpatialData\Assignments\01-Python_Foundations\04-Foundations\Lessons\03-Work_With_Files
#
#
#  Directory of c:\Users\Victoria Heredia\Downloads\4543_SpatialData\Assignments\01-Python_Foundations\04-Foundations\Lessons\03-Work_With_Files
#
#
#  Directory of c:\Users\Victoria Heredia\Downloads\4543_SpatialData\Assignments\01-Python_Foundations\04-Foundations\Lessons\03-Work_With_Files
#
#
#  Directory of c:\Users\Victoria Heredia\Downloads\4543_SpatialData\Assignments\01-Python_Foundations\04-Foundations\Lessons\03-Work_With_Files
# File Not Found

# %%
# %cd ..  # Change to parent directory
# %pwd
# Out:
# [WinError 2] The system cannot find the file specified: '.. # Change to parent directory'
# c:\Users\Victoria Heredia\Downloads\4543_SpatialData\Assignments\01-Python_Foundations\04-Foundations\Lessons\03-Work_With_Files
# 'c:\\Users\\Victoria Heredia\\Downloads\\4543_SpatialData\\Assignments\\01-Python_Foundations\\04-Foundations\\Lessons\\03-Work_With_Files'

# %% [markdown]
# ✅ **Your Turn**: Navigate into a subfolder of your repo (e.g., `Foundations/`) and list its contents.

# %%
# %cd "c:\Users\Victoria Heredia\Downloads\4543_SpatialData\Assignments\01-Python_Foundations\04-Foundations\Lessons\03-Work_With_Files"
# %pwd
# %ls
# Out:
# c:\Users\Victoria Heredia\Downloads\4543_SpatialData\Assignments\01-Python_Foundations\04-Foundations\Lessons\03-Work_With_Files
#  Volume in drive C is Windows
#  Volume Serial Number is 389D-1836
#
#  Directory of c:\Users\Victoria Heredia\Downloads\4543_SpatialData\Assignments\01-Python_Foundations\04-Foundations\Lessons\03-Work_With_Files
#
# 04/12/2026  11:10 PM    <DIR>          .
# 03/21/2026  07:22 PM    <DIR>          ..
# 03/21/2026  07:20 PM                25 _autogen.md
# 03/21/2026  07:20 PM                24 _header.md
# 04/12/2026  11:18 PM             9,130 03-Work_With_Files.ipynb
# 04/12/2026  11:10 PM                39 example.txt
# 03/21/2026  07:20 PM                41 meta.yaml
# 03/21/2026  07:20 PM                18 README.md
#                6 File(s)          9,277 bytes
#                2 Dir(s)  100,512,432,128 bytes free

# %% [markdown]
# ## 2. Writing and Reading Text Files

# %%
# Writing to a text file
with open("example.txt", "w") as f:
    f.write("Hello, Jupyter!\n")
    f.write("This is a text file.\n")

# %%
# Reading from a text file
with open("example.txt", "r") as f:
    contents = f.read()
contents

# %% [markdown]
# ✅ **Your Turn**: Write your name into a file called `me.txt`, then read it back and print the result.

# %%
with open("me.txt", "w") as file:
    file.write("Victoria Heredia")
    
with open("me.txt", "r") as file:
    content = file.read()
    print(content)
# Out:
# Victoria Heredia

# %% [markdown]
# ## 3. JSON Files

# %%
import json

data = {"name": "Graylian", "type": "mascot", "skills": ["howl", "parrot talk"]}

# Write JSON
with open("data.json", "w") as f:
    json.dump(data, f)

# Read JSON
with open("data.json", "r") as f:
    loaded = json.load(f)
loaded

# %% [markdown]
# ✅ **Your Turn**: Create a dictionary with your name and 2-3 favorite courses. Save it to `courses.json`, then read it back.

# %%
import json

data = {
    "name": "Victoria Heredia",
    "courses": ["Theory of Computation", "Computer Communications and Networks", "Spatial Data"]
}

with open("courses.json", "w") as file:
    json.dump(data, file)

# %% [markdown]
# ## 4. CSV Files

# %%
import csv

# Writing CSV
rows = [["Name", "Score"], ["Alice", 90], ["Bob", 85]]
with open("scores.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerows(rows)

# Reading CSV
with open("scores.csv", "r") as f:
    reader = csv.reader(f)
    for row in reader:
        print(row)

# %% [markdown]
# ✅ **Your Turn**: Create a CSV with 3 rows of your own data (e.g., pets, grades, or hobbies). Read it back and display the rows.

# %%
import csv

with open("data.csv", "w", newline="") as file:
    writer = csv.writer(file)

    writer.writerow(["Name", "Type", "Value"])
    writer.writerow(["Dog", "Pet", "Buddy"])
    writer.writerow(["Python", "Course", "A"])
    writer.writerow(["Volley", "Hobby", "Fun"])

# %% [markdown]
# ---
# ### Summary
# - `%pwd`, `%ls`, `%cd` show you where you are in the filesystem.
# - Use `with open(...)` to safely read/write files.
# - JSON is for structured data (key/value).
# - CSV is for tabular data (rows/columns).
# - Managing files is step 1 in any real data science project.
