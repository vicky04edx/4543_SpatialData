# %% [markdown]
# # 📘 CodeSpace Intro
#
# Welcome to your first Jupyter notebook in CodeSpace's! If it's not, that's ok, this will be real easy.

# %% [markdown]
# ## ✅ Learning Goals
# - Run cells in a notebook
# - Edit Markdown and code
# - Save a copy to your own Drive

# %%
# 👋 Try running this cell!
print('Hello, Python Spatial World!')
# Out:
# Hello, Python Spatial World!

# %% [markdown]
# ## ✏️ Your Turn
# Modify the code below to print your name.

# %%
print('Terry')
# Out:
# Terry

# %% [markdown]
# ## 💾 Save a Copy
# - Go to **File > Save a copy in Colabs**.
# - Make sure it changed on your github repo.
#
# Move it to your `completed` folder.

# %%
import geojsonio
from geojsonio import display
import json
from IPython.display import display

with open('campus_world.geojson') as f:
    geojson_data = json.load(f)
    display(geojson_data)
# Convert the dictionary to a JSON string if needed, 
# though the library often handles the dict directly
# contents = json.dumps(geojson_data) 

# Embed the geojson.io map
# The display function is an alias for embed() in the library

# display(geojsonio.embed(geojson_data))
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'Name': 'Bolin Hall',
#     'marker-color': '#FF0000',
#     'marker-size': 'large',
#     'marker-symbol': 'soccer',
#     'fill': '#C392ff',
#     'fill-width': 1,
#     'fill-opacity': 0.25},
#    'geometry': {'type': 'Point', 'coordinates': [-98.51947, 33.87372]},
#    'id': 0},
#   {'type': 'Feature',
#    'properties': {'Name': 'Bookstore',
#     'marker-color': '#00ff00',
#     'marker-symbol': 'library',
#     'marker-size': 'large'},
#    'geometry': {'coordinates': [-98.52054301247594, 33.873957083293334],
#     'type': 'Point'},
#    'id': 1},
#   {'type': 'Feature',
#    'properties': {'name': 'Coffee shop',
#     'marker-color': '#a0a0a0',
#     'marker-size': 'large',
#     'marker-symbol': 'cafe'},
#    'geometry': {'coordinates': [-98.51805044396598, 33.87010225735909],
#     'type': 'Point'},
#    'id': 11},
#   {'type': 'Feature',
#    'properties': {'name': 'bounding box',
# ...

# %%
from geojsonio import display

with open('campus_world.geojson') as f:
    contents = f.read()
    display(contents)
